# %% [markdown]
# #Prototipo 2: GRUPO 9 TDI

# %% [markdown]
# Pasos para utilizar este Jupyter Notebok
#
# 1.   En primer lugar, para probar este modelo tienes que subir el archivo de imágen satelital a la sección de archivos de este mismo.
# 2.   Poner el nombre del archivo en apartado que el propio código te lo indica
#
# 3. Ejecutar la celda correspondiente

# %% [markdown]
# # PRUEBALO AQUÍ

# %%
#importamos biblioteca que sirve para conectarnos a internet
import requests
#definimos URL del servicio que nos vamos a conectar
url = 'https://www.nyckel.com/v1/functions/0w4f0qu3t3u30mse/invoke'

#Variable de interés
headers = {
    'Authorization': 'Bearer ' + 'eyJhbGciOiJSUzI1NiIsInR5cCI6ImF0K2p3dCJ9.eyJuYmYiOjE2Mzc2MjcyNjcsImV4cCI6MTYzNzYzMDg2NywiaXNzIjoiaHR0cHM6Ly93d3cubnlja2VsLmNvbSIsImNsaWVudF9pZCI6IjYxa3EwN3owdmt5OTZ5aTNjb2tlczY3YjVqNWZub3RiIiwianRpIjoiMDFDNTI5N0MzRTFDQjY2Njk0NjBBNkJCMzQ1Rjk3OEIiLCJpYXQiOjE2Mzc2MjcyNjcsInNjb3BlIjpbImFwaSJdfQ.Mb7Lw7K1T8I-2xFZJex2Jy_wQCKRMgHYSVddtV2Ig4gN0tJFqEqkNgKWtbuANkp1gkIdE0eNn4LJrlYlcoxc3SH2-0qunogHxXtgJS9za1wCld2_KxFhib-hjNffEhTT0l3onHtpcr_xJcmtAf85gMFGTFmSxqlg3s26Ds85xPa8CpVbB0oO4eJTmH97OYjBZuII0PztIrzR2BD5ZD4v5u_4vZlFvN3tt72dXBP07v_MH7oHSCwWxjLuFSSABnStcs211FeMcQFEgEIF3oa2RJQe0wbSktvCIbk2TzQ9J8lyVkJYCXwlvzi_dtZHWeCAzW41XIZE_Rim42CvBbkIDQ',
}

#aqui abrimos la imágen a analizar
#lo ideal es que el archivo sea .jpg o png, es decir un screenshot de una locación de mapa
with open('nombre_archivo.extension', 'rb') as f:
    #obtenemos la respuesta del clasficador
    result = requests.post(url, headers=headers, files={'data': f})
print(result.text)
# Out:
# {"labelName":"Presencia de castores","labelId":"label_j642qjqi8i3c71c4","confidence":0.7822522952654438}

# %% [markdown]
# # TESTEOS

# %% [markdown]
# Test 1: Probamos una imágen donde efectivamente hubo presencia de castores

# %% [markdown]
# ![test1.png](data:image/png;base64,...)

# %%
import requests
url = 'https://www.nyckel.com/v1/functions/0w4f0qu3t3u30mse/invoke'

headers = {
    'Authorization': 'Bearer ' + 'eyJhbGciOiJSUzI1NiIsInR5cCI6ImF0K2p3dCJ9.eyJuYmYiOjE2Mzc2MjcyNjcsImV4cCI6MTYzNzYzMDg2NywiaXNzIjoiaHR0cHM6Ly93d3cubnlja2VsLmNvbSIsImNsaWVudF9pZCI6IjYxa3EwN3owdmt5OTZ5aTNjb2tlczY3YjVqNWZub3RiIiwianRpIjoiMDFDNTI5N0MzRTFDQjY2Njk0NjBBNkJCMzQ1Rjk3OEIiLCJpYXQiOjE2Mzc2MjcyNjcsInNjb3BlIjpbImFwaSJdfQ.Mb7Lw7K1T8I-2xFZJex2Jy_wQCKRMgHYSVddtV2Ig4gN0tJFqEqkNgKWtbuANkp1gkIdE0eNn4LJrlYlcoxc3SH2-0qunogHxXtgJS9za1wCld2_KxFhib-hjNffEhTT0l3onHtpcr_xJcmtAf85gMFGTFmSxqlg3s26Ds85xPa8CpVbB0oO4eJTmH97OYjBZuII0PztIrzR2BD5ZD4v5u_4vZlFvN3tt72dXBP07v_MH7oHSCwWxjLuFSSABnStcs211FeMcQFEgEIF3oa2RJQe0wbSktvCIbk2TzQ9J8lyVkJYCXwlvzi_dtZHWeCAzW41XIZE_Rim42CvBbkIDQ',
}


with open('test1.png', 'rb') as f:
    result = requests.post(url, headers=headers, files={'data': f})
print(result.text)
# Out:
# {"labelName":"Presencia de castores","labelId":"label_j642qjqi8i3c71c4","confidence":0.7822522952654438}

# %% [markdown]
# Para este test, el clasificador logró identificar con éxito la presencia de castores en esta área, con un nivel de confianza de un 78%. Esto se debe a que en esta imágen los troncos caidos son notorias

# %% [markdown]
# Test 2: probamos una imágen donde no hay presencia de castores

# %% [markdown]
# ![no2.png](data:image/png;base64,...)

# %%
import requests
url = 'https://www.nyckel.com/v1/functions/0w4f0qu3t3u30mse/invoke'

headers = {
    'Authorization': 'Bearer ' + 'eyJhbGciOiJSUzI1NiIsInR5cCI6ImF0K2p3dCJ9.eyJuYmYiOjE2Mzc2MjcyNjcsImV4cCI6MTYzNzYzMDg2NywiaXNzIjoiaHR0cHM6Ly93d3cubnlja2VsLmNvbSIsImNsaWVudF9pZCI6IjYxa3EwN3owdmt5OTZ5aTNjb2tlczY3YjVqNWZub3RiIiwianRpIjoiMDFDNTI5N0MzRTFDQjY2Njk0NjBBNkJCMzQ1Rjk3OEIiLCJpYXQiOjE2Mzc2MjcyNjcsInNjb3BlIjpbImFwaSJdfQ.Mb7Lw7K1T8I-2xFZJex2Jy_wQCKRMgHYSVddtV2Ig4gN0tJFqEqkNgKWtbuANkp1gkIdE0eNn4LJrlYlcoxc3SH2-0qunogHxXtgJS9za1wCld2_KxFhib-hjNffEhTT0l3onHtpcr_xJcmtAf85gMFGTFmSxqlg3s26Ds85xPa8CpVbB0oO4eJTmH97OYjBZuII0PztIrzR2BD5ZD4v5u_4vZlFvN3tt72dXBP07v_MH7oHSCwWxjLuFSSABnStcs211FeMcQFEgEIF3oa2RJQe0wbSktvCIbk2TzQ9J8lyVkJYCXwlvzi_dtZHWeCAzW41XIZE_Rim42CvBbkIDQ',
}


with open('no2.png', 'rb') as f:
    result = requests.post(url, headers=headers, files={'data': f})
print(result.text)
# Out:
# {"labelName":"No presencia de castores","labelId":"label_1c0vgn96frpqc52s","confidence":0.664769085452962}

# %% [markdown]
# Para este test, el clasificador logró identificar con éxito la NO presencia de castores en esta área, con un nivel de confianza de un 66%.
